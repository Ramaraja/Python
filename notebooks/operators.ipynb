# %%
print ("operators")

s="test"

# %%
# Equal

a = 10
b = 20

a == b
# Out:
# False

# %%
[1,2,3] == [1,2,2]
# Out:
# False

# %%
# not equal

a != b

if (a != b):
    print ("True")
else:
    print ("False")
# Out:
# True

# %%
# greater than

a > b
# Out:
# False

# %%
# less than

a < b
# Out:
# True

# %%
# try
# >= and <=

# %%
# chained operator - logical operator

c = 30 
d = 10

a != b and d == a
# Out:
# True

# %%
c = 30 
d = 10

a == b or d == a
# Out:
# True

# %%
a > b < c
# Out:
# False
