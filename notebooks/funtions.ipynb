# %%
# funtions

x = 1
y = 3

print (x+y)
# Out:
# 4

# %%
def name_of_the_funtion(arg1, arg2, . .):
    # your logic

# %%
def add(x,y):
    return x+y

def sub(x,y):
    return x-y

def mul(x,y):
    return x*y

def do_nothing():
    print ("no logic found")

# %%
do_nothing()
# Out:
# no logic found

# %%
add(5,5)
# Out:
# 10

# %%
sub(5,5)
# Out:
# 0

# %%
mul(5,5)
# Out:
# 25

# %%
# i have a mrp
# wanted to mention gst %
# return tax

# %%
mrp = 30
tax_percent = 2

tax = mrp+(mrp*(2/100))
print (tax)
# Out:
# 30.3

# %%
def calc_tax(mrp, product=None):
    if (product == "PHARMA"):
        tax_percent=1
        return  mrp+(mrp*(tax_percent/100))
    elif (product == "STATIONARY"):
        tax_percent=2
        return  mrp+(mrp*(tax_percent/100))

# %%
product ="PHARMA"
calc_tax(10, product=product)
# Out:
# 10.1
