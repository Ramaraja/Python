# %%
# Python statments

# %%
a = 10 
b = 20
c = 30

# %%
# if

if (a < b):
    c = 10
    print (c)
# Out:
# 10

# %%
if (a < b):
    if (a < c):
        print ("true")
# Out:
# true

# %%
if (a < b) and (a < c):
    print ("true")
# Out:
# true

# %%
# else

if (a > b):
    print ("a is greater")
else:
    print ("b is greater")
# Out:
# b is greater

# %%
# else if

if (a > b):
    print ("a is greater")
elif (a < c):
    print (a)
elif (c == a):
    print (c)
else:
    print (c)
# Out:
# 10

# %%
if (a > b):
    print ("a is greater")
if (a < c):
    print (a)
else:
    print (c)
